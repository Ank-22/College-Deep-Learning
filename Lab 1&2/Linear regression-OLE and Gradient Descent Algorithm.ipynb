# %% [markdown]
# Linear Regression
# Reference-- https://towardsdatascience.com/linear-regression-from-scratch-cd0dee067f72

# %% [markdown]
# Upload Dataset

# %% [markdown]
# What is Linear Regression?
# Linear Regression is a method used to define a relationship between a dependent variable (Y) and independent variable (X). Which is simply written as :

# %%
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-62b9b06d-5615-4e5c-9c39-e97bcf925399" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62b9b06d-5615-4e5c-9c39-e97bcf925399">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datasets_17180_22577_test.csv to datasets_17180_22577_test.csv

# %% [markdown]
# What is Linear Regression?
# Linear Regression is a method used to define a relationship between a dependent variable (Y) and independent variable (X). Which is simply written as
# :

# %%
#import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv("datasets_17180_22577_test.csv")
print(datasets_17180_22577_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d34020bad0b0> in <module>()
#       5 import pandas as pd
#       6 dataset = pd.read_csv("datasets_17180_22577_test.csv")
# ----> 7 print(datasets_17180_22577_test)
#       8
#
# NameError: name 'datasets_17180_22577_test' is not defined

# %% [markdown]
# **Ordinary Least Mean Square -Linear Regression **

# %%
# initializing our inputs and outputs
X = dataset['Head Size(cm^3)'].values
Y = dataset['Brain Weight(grams)'].values
# mean of our inputs and outputs
x_mean = np.mean(X)
y_mean = np.mean(Y)
#total number of values
n = len(X)
# using the formula to calculate the b1 and b0
numerator = 0
denominator = 0
for i in range(n):
    numerator += (X[i] - x_mean) * (Y[i] - y_mean)
    denominator += (X[i] - x_mean) ** 2
    
b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)
#printing the coefficient
print(b1, b0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-c8b1ffc05a7b> in <module>()
#       1 # initializing our inputs and outputs
# ----> 2 X = dataset['Head Size(cm^3)'].values
#       3 Y = dataset['Brain Weight(grams)'].values
#       4 # mean of our inputs and outputs
#       5 x_mean = np.mean(X)
#
# KeyError: 'Head Size(cm^3)'

# %% [markdown]
# **Plot Graphically **

# %%
#plotting values 
x_max = np.max(X) + 100
x_min = np.min(X) - 100
#calculating line values of x and y
x = np.linspace(x_min, x_max, 1000)
y = b0 + b1 * x
#plotting line 
plt.plot(x, y, color='#00ff00', label='Linear Regression')
#plot the data point
plt.scatter(X, Y, color='#ff0000', label='Data Point')
# x-axis label
plt.xlabel('Head Size (cm^3)')
#y-axis label
plt.ylabel('Brain Weight (grams)')
plt.legend()
plt.show()

# %% [markdown]
# Root Mean Squared Error is the square root of the sum of all errors divided by the number of values, or Mathematically
# ![1_SGBsn7WytmYYbuTgDatIpw.gif](data:image/gif;base64,...)

# %%
rmse = 0
for i in range(n):
    y_pred=  b0 + b1* X[i]
    rmse += (Y[i] - y_pred) ** 2
    
rmse = np.sqrt(rmse/n)
print(rmse)
# Out:
# 72.1206213783709

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7d91cbe7-dc68-403f-b345-c43ef8792e67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d91cbe7-dc68-403f-b345-c43ef8792e67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data.csv

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv('Data.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()


#Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate(0.001 to 0.0001)
epochs =5 # The number of iterations to perform gradient descent

   
n = float(len(X)) # Number of elements in X

    # Performing Gradient Descent
for i in range(epochs):
        Y_pred = m*X + c  # The current predicted value of Y
        D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
        D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
 
        m = m - L * D_m  # Update m
        c = c - L * D_c  # Update c
        error=sum((Y - Y_pred))
        print (error)
        print (m, c)
        # Making predictions
        Y_pred = m*X + c

        
        
   
print (m, c)

# Making predictions
Y_pred = m*X + c
"""
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()"""
# Out:
# 7186.632372389998
# 0.7448958907352418 0.014666596678346935
# 3596.352142490129
# 1.115714753875792 0.022006090846694137
# 1809.0601952749796
# 1.300312830819979 0.025698050428887974
# 919.3210800892901
# 1.3922075909271796 0.027574215898457953
# 476.3963419141144
# 1.4379533408857632 0.028546453330935737
# 1.4379533408857632 0.028546453330935737
